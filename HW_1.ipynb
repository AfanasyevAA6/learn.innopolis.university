# %% [markdown]
# Формулировка задания: Решить задачи по высшей математике. Решить матрицы
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %%
# create a fuction
def multiply(x,y):
  for i in range(len(x)):
    # iterate through columns of y
    for j in range(len(y[0])):
        # iterate through rows of y
        for k in range(len(y)):
            result[i][j] += x[i][k] * y[k][j]

  for r in result:
    print(r)

# %%
result = [[0]]
# 3x1 matrix
X = [[6,-8,3]]
# 1x3 matrix
Y = [[1,],
    [1,],
    [4,]]
multiply(X,Y)
# Out:
# [10]

# %%
result = [[0,0],[0,0],[0,0],[0,0]]
# 2x4 matrix
X = [[-3,-7],
    [-10,6],
    [0,-6],
     [-1,-3]]
# 2x2 matrix
Y = [[-8,9],
      [4,-2]]
multiply(X,Y)
# Out:
# [-4, -13]
# [104, -102]
# [-24, 12]
# [-4, -3]
